# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantkumartalan43/Exercise/blob/main/python_basics_week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Functions

def greet():
  print("Welcome to python")

greet()
# Out:
# Welcome to python

# %%
def customer_summary(name, city):
  print(f"Customer: {name}")
  print(f"city: {city}")

customer_summary("John", "New York")
# Out:
# Customer: John
# city: New York

# %%
def add_numbers(a, b):
  print(a + b)

add_numbers(10, 20)
# Out:
# 30

# %%
def add_numbers(a, b):
  return a + b

result = add_numbers(10, 20)
print(result)
# Out:
# 30

# %%
def calculate_avg(numbers):
  return sum(numbers) / len(numbers)

marks = [45, 67, 55, 39, 78, 99]

avg = calculate_avg(marks)
print(avg)
# Out:
# 63.833333333333336

# %%
def check_even(number):
  if number % 2 == 0:
    return "even"

  return "odd"

print(check_even(10))
print(check_even(15))
# Out:
# even
# odd

# %%
def customer_type(purchase):
  if purchase >= 50000:
    return "Premium"

  return "Regular"

print(customer_type(75000))
print(customer_type(45000))
# Out:
# Premium
# Regular

# %%
def print_numbers():
  for i in range(1,6):
    print(i)

print_numbers()
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def grade(marks):

  if marks >= 90:
    return "A"

  elif marks >= 75:
    return "B"

  elif marks >= 50:
    return "C"

  return "Fail"

print(grade(88))
print(grade(65))
print(grade(45))
# Out:
# B
# C
# Fail

# %%
sales = [12000, 15000, 18000, 14000, 21000]

# %%
def calculate_total(sales):
  return sum(sales)

total = calculate_total(sales)
print("Sum of sales:", total)

def calculate_avg(sales):
  return sum(sales) / len(sales)

avg = calculate_avg(sales)
print("Average of sales:", avg)

def highest_sales(sales):
  return max(sales)

max_sale = highest_sales(sales)
print("Maximum sale:", max_sale)

def lowest_sales(sales):
  return min(sales)

min_sale = lowest_sales(sales)
print("Minimum sale:", min_sale)
# Out:
# Sum of sales: 80000
# Average of sales: 16000.0
# Maximum sale: 21000
# Minimum sale: 12000

# %%
def sales_report(month="current month"):
  print(f'Sales report for {month}')

sales_report()
sales_report("April")
# Out:
# Sales report for current month
# Sales report for April

# %%
def sales_report(month, revenue, profit):
  print(month, revenue, profit)

sales_report(month="April", revenue=20000, profit=5000)
# Out:
# April 20000 5000

# %%
def sales_stats(sales):
  total = sum(sales)
  avg = sum(sales) / len(sales)
  return total, avg

sales = [1000, 2000, 3000]

total, avg = sales_stats(sales)
print(total, avg)
# Out:
# 6000 2000.0

# %%
def add_numbers(*args):
  return sum(args)

print(add_numbers(10, 20, 30))
print(add_numbers(10, 20, 30, 40, 50))
# Out:
# 60
# 150

# %%
def sales(**kwargs):
  print(kwargs)

sales(month="april", revenue = 40000, profit = 10000)
# Out:
# {'month': 'april', 'revenue': 40000, 'profit': 10000}

# %%
def report(**metrics):
  for key, values in metrics.items():
    print(key, values)

print(report(month="april", revenue = 40000, profit = 10000))
# Out:
# month april
# revenue 40000
# profit 10000
# None

# %%
# lambda

def square(x):
  return x * x

square = lambda x: x * x

print(square(5))
# Out:
# 25

# %%
add = lambda x, y: x + y

print(add(10, 20))
# Out:
# 30

# %%
grade = lambda marks: "Pass" if marks >= 40 else "Fail"

print(grade(65))
# Out:
# Pass

# %%
check_even = lambda number: "even" if number % 2 == 0 else "odd"

print(check_even(10))
# Out:
# even

# %%
for i in range(3):
  for j in range(2):
    print(i, j)
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
# 2 0
# 2 1

# %%
for i in range(1, 6):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5, 0, -1):
  print("*" * i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, 6):
  for j in range(i):
    print("*", end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for num in range(1, 5):
  print(f'\nTable of {num}')

  for i in range(1, 11):
    print(num, "x", i, "=", num * i)
# Out:
# Table of 1
# 1 x 1 = 1
# 1 x 2 = 2
# 1 x 3 = 3
# 1 x 4 = 4
# 1 x 5 = 5
# 1 x 6 = 6
# 1 x 7 = 7
# 1 x 8 = 8
# 1 x 9 = 9
# 1 x 10 = 10
#
# Table of 2
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# 2 x 10 = 20
#
# Table of 3
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# 3 x 10 = 30
#
# Table of 4
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# 4 x 10 = 40

# %%
marks = [78, 85, 90, -5]

for mark in marks:
  if mark < 0:
    print("Invalid marks")
    break
# Out:
# Invalid marks

# %%
for i in range(1, 6):
  for j in range(1, 1+i):
    print(j, end="")

  print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
marks = [
    [78, 85, 90],
    [67, 88, 92],
    [95, 81, 79]
]

highest = marks[0][0]

for student in marks:

    for mark in student:

        if mark > highest:
            highest = mark

print("Highest Mark =", highest)
# Out:
# Highest Mark = 95

# %%
customers = [
    101,
    102,
    103,
    101,
    102]

# %%
unique_customers = set(customers)
print(unique_customers)
# Out:
# {101, 102, 103}

# %%
cities = {
    "Delhi",
    "Mumbai",
    "Pune"
}

if "Delhi" in cities:
    print("Found")
# Out:
# Found

# %%
day1 = {
    "Rahul",
    "Amit",
    "Priya"
}

day2 = {
    "Priya",
    "Amit",
    "Vikas"
}

print(day1 & day2)
# Out:
# {'Priya', 'Amit'}

# %%
data = [
    10,
    20,
    10,
    30,
    20,
    40
]

unique_data = list(set(data))

print(unique_data)
# Out:
# [40, 10, 20, 30]

# %%
cities = [
    "Delhi",
    "Mumbai",
    "Delhi",
    "Pune",
    "Mumbai"
]

unique_cities = set(cities)

print("Unique Cities:", unique_cities)
print("Count:", len(unique_cities))
# Out:
# Unique Cities: {'Delhi', 'Pune', 'Mumbai'}
# Count: 3

# %%
try:
    num = int(input("Enter a number:"))
    print(num)
except:
    print("Invalid input")
# Out:
# Enter a number:abc
# Invalid input

# %%
try:
    num = int(input("Enter number: "))
    print(num)

except ValueError:
    print("Please enter a valid number")
# Out:
# Enter number: abc
# Please enter a valid number

# %%
try:

    num = int(input("Enter number: "))
    result = 100 / num

except ValueError:
    print("Invalid Number")

except ZeroDivisionError:
    print("Cannot Divide by Zero")
# Out:
# Enter number: 0
# Cannot Divide by Zero

# %%
try:
    num = int(input("Enter a number:"))
    print(num)
except:
    print("Invalid input")

else:
  print("Valid number")
# Out:
# Enter a number:10
# 10
# Valid number

# %%
while True:
  try:
    age = int(input("Enter your age:"))
    break

  except ValueError:
    print("Please enter a valid age")
# Out:
# Enter your age:hg
# Please enter a valid age
# Enter your age:56

# %%
marks = []

for i in range(3):

  while True:

    try:
      mark = float(input("Enter your mark:"))
      marks.append(mark)
      break

    except ValueError:
      print("Invalid mark")
# Out:
# Enter your mark:abc
# Invalid mark
# Enter your mark:45
# Enter your mark:34
# Enter your mark:56

# %%
age = -5

if age < 0:
  raise ValueError("Age cannot be negative")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1913/2424222348.py in <cell line: 0>()
#       2
#       3 if age < 0:
# ----> 4   raise ValueError("Age cannot be negative")
#
# ValueError: Age cannot be negative

# %%
while True:

  try:
    mark = float(input("Enter your marks:"))
    if mark < 0 or mark > 100:
      raise ValueError

    print("Valid marks")
    break

  except ValueError:
    print("Marks must be between 0 and 100")
# Out:
# Enter your marks:-5
# Marks must be between 0 and 100
# Enter your marks:45
# Valid marks

# %%
expenses = []

for i in range(3):
  while True:
    try:
      expense = float(input("Enter your expense:"))
      if expense < 0:
        raise ValueError
      expenses.append(expense)
      break

    except ValueError:
      print("Invalid expense")

print(sum(expenses))
# Out:
# Enter your expense:-5
# Invalid expense
# Enter your expense:4500
# Enter your expense:5600
# Enter your expense:3000
# 13100.0

# %%
sales = []

for i in range(5):
  while True:
    try:
      sale = float(input("Enter your sale:"))
      if sale < 0:
        raise ValueError
      sales.append(sale)
      break

    except ValueError:
      print("Invalid sale")

print("Total sales:", sum(sales))
print("Average sales:", sum(sales) / len(sales))
print("Highest sale:", max(sales))
print("Lowest sale:", min(sales))
# Out:
# Enter your sale:-5000
# Invalid sale
# Enter your sale:abc
# Invalid sale
# Enter your sale:50000
# Enter your sale:34000
# Enter your sale:28000
# Enter your sale:67000
# Enter your sale:72000
# Total sales: 251000.0
# Average sales: 50200.0
# Highest sale: 72000.0
# Lowest sale: 28000.0

# %%
# opening files

# open(filename, mode)

# file = open("data.txt", "r")

# %%
# file = open("sample.txt", "r")

# content = file.read()

# print(content)

# file.close()

# %%
# with open("sample.txt", "r") as file:
#    content = file.read()

# %%
# reading line by line

with open("sample.txt", "r") as file:
  for line in file:
    print(line.strip())

# %%
# writing a file

with open("notes.txt", "w") as file:

    file.write("Python is awesome")

# %%
# appending a file

with open("notes.txt", "a") as file:

    file.write("\nNew Entry")

# %%
sale = 1500

with open("sales.txt", "w") as file:
  file.write(f"{sale}\n")

# %%
with open("sales.txt", "r") as file:
  lines = file.readlines()

print(lines)
# Out:
# ['1500\n']

# %%
sales = []

with open("sales.txt", "r") as file:
  for line in file:
    sales.append(int(line.strip()))

print(sales)
# Out:
# [1500]

# %%
# reading csv files

with open("employee.csv", "r") as file:
  for line in line:
    print(line.strip())

# %%
# splitting csv

with open("employee.csv", "r") as file:
  for line in line:
    row = line.strip().split(",")

    print(row)

# %%
note = input("Enter a note:")
with open("notes.txt", "a") as file:
  file.write(note + "\n")

print("Saved")
# Out:
# Enter a note:This is a note.
# Saved

# %%
expense = float(
    input("Enter expense: ")
)

with open("expenses.txt", "a") as file:

    file.write(str(expense) + "\n")

# %%
expenses = []

with open("expenses.txt", "r") as file:

    for line in file:

        expenses.append(
            float(line.strip())
        )

print(sum(expenses))

# %%
try:
  with open("sample.txt", "r") as file:
    print(file.read())
except FileNotFoundError:
  print("file not found")
# Out:
# file not found

# %%
# Create a function that returns cube of a number

def cube(*args):
  return sum(args) ** 3

print(cube(9))
# Out:
# 729

# %%
# Create a function that accepts unlimited numbers and returns average

def avg(*args):
  return sum(args) / len(args)

print(avg(10, 20, 30))
# Out:
# 20.0

# %%
while True:

  try:
    age = int(input("Enter your age:"))
    if age < 0:
      raise ValueError

    print("Valid age")
    break

  except ValueError:
    print("Invalid age")
# Out:
# Enter your age:-5
# Invalid age
# Enter your age:23
# Valid age

# %%
def load_sales(sales):
  sales = []

  with open("sales.txt", "r") as file:
    for line in file:
      sales.append(float(line.strip()))

  return sales

# %%
def analyze_sales(sales):

  return{
      "total": sum(sales),
      "average": sum(sales) / len(sales),
      "highest": max(sales),
      "lowest": min(sales)
  }

# %%
def print_report(results):

  print("\nSales Report")
  print("-------------")

  for key, value in results.items():
    print(f"{key}:Rs{value:.2f}")

# %%
try:
  sales = load_sales("sales.txt")

  report = analyze_sales(sales)

  print_report(report)

except FileNotFoundError:
  print("File not found")
# Out:
# Sales Report
# -------------
# total:Rs115000.00
# average:Rs16428.57
# highest:Rs21000.00
# lowest:Rs12000.00

# %%
# Object Oriented Programming

class ClassName:
  pass

# %%
class Customer:
  pass

customer1 = Customer()
print(customer1)

# %%
class Customer:
  name = "Rahul"

customer1 = Customer()
print(customer1.name)
# Out:
# Rahul

# %%
class Customer:
  def __init__(self, name):
    self.name = name

# %%
customer1 = Customer("Rahul")
customer2 = Customer("Amit")

print(customer1.name)
print(customer2.name)
# Out:
# Rahul
# Amit

# %%
class Customer:
  def __init__(self, name, city, purchase):
    self.name = name
    self.city = city
    self.purchase = purchase

# %%
customer = Customer(
    "Rahul",
    "Delhi",
    50000
)

print(customer.name)
print(customer.city)
print(customer.purchase)
# Out:
# Rahul
# Delhi
# 50000

# %%
class Customer:
  def __init__(self, name):
    self.name = name

  def greet(self):
    print(f"Hello {self.name}")

customer = Customer("Rahul")
customer.greet()
# Out:
# Hello Rahul

# %%
class Customer:
  def __init__(self, name, purchase):

    self.name = name
    self.purchase = purchase

  def customer_type(self):

    if self.purchase > 50000:
      return "Premium"

    return "Regular"

# %%
customer = Customer("Rahul", 60000)

print(customer.customer_type())
# Out:
# Premium

# %%
c1 = Customer("Rahul", 60000)
c2 = Customer("Amit", 72000)

# %%
class Customer:
  def __init__(self, name, salary):

    self.name = name
    self.salary = salary

  def annual_salary(self):
    return self.salary * 12

c1 = Customer("Rahul", 50000)

print(c1.annual_salary())
# Out:
# 600000

# %%
class Product:
  def __init__(self, name, price):

    self.name = name
    self.price = price

  def discounted_price(self, discount):

    return(self.price * (1 - discount / 100))

# %%
product = Product("Laptop", 50000)

print(product.discounted_price(10))
# Out:
# 45000.0

# %%
class SalesRecord:
  def __init__(self, month, sales):

    self.month = month
    self.sales = sales

  def display(self):

    print(self.month,
          self.sales)

record = SalesRecord("January", 15000)
print(record.display())
# Out:
# January 15000
# None
